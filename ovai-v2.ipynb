# %%
# Step 1: Install Git
import os
# !apt-get install git -y
# !git clone --branch branch3 https://github.com/MMaslowski12/OvercookedAI-coop.git
# %cd /kaggle/working/OvercookedAI-coop
main_dir = os.getcwd()
# Out:
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# 0 upgraded, 0 newly installed, 0 to remove and 132 not upgraded.
# Cloning into 'OvercookedAI-coop'...
# remote: Enumerating objects: 2259, done.
# remote: Counting objects: 100% (859/859), done.
# remote: Compressing objects: 100% (748/748), done.
# remote: Total 2259 (delta 175), reused 785 (delta 108), pack-reused 1400 (from 1)
# Receiving objects: 100% (2259/2259), 32.69 MiB | 42.11 MiB/s, done.
# Resolving deltas: 100% (420/420), done.
# /kaggle/working/OvercookedAI-coop

# %%
from venv_script import activate_venv, get_requirements, setup_venv
import subprocess
import sys
print(sys.executable)
print("XD")
# !apt install python3.10-venv
print("installed")
venv_python = activate_venv()
print("activated")
setup_venv(venv_python)
print("set up")
# Out:
# /usr/bin/python3
# XD
#
#
#
# The following additional packages will be installed:
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib python3-pip-whl
#   python3-setuptools-whl python3.10 python3.10-dev python3.10-minimal
# Suggested packages:
#   python3.10-doc binfmt-support
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# The following packages will be upgraded:
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib python3.10
#   python3.10-dev python3.10-minimal
# 7 upgraded, 3 newly installed, 0 to remove and 125 not upgraded.
# Need to get 15.1 MB of archives.
# After this operation, 2,914 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-dev amd64 3.10.12-1~22.04.7 [508 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-dev amd64 3.10.12-1~22.04.7 [4,762 kB]
# ...

# %%
subprocess.check_call(f"{venv_python} -m pip install ipykernel", shell=True)

#install compatible cuda libraries
subprocess.check_call(f"{venv_python} -m pip install -U nvidia-cudnn-cu11", shell=True)
# Out:
# 0

# %%
subprocess.check_call("nvcc --version", shell=True)
# Out:
# 0

# %%
print(venv_python)
# Out:
# venv/bin/python

# %%
subprocess.check_call(f"{venv_python} -m jupyter nbconvert --to script Game.ipynb", shell=True)
# !pwd
# !/kaggle/working/OvercookedAI-coop/venv/bin/python Game.py
# !/venv/bin/python Game.py

# subprocess.check_call(f"{venv_python} Game.py", shell=True)
# Out:
# /kaggle/working/OvercookedAI-coop
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'log'
# Traceback (most recent call last):
#   File "/kaggle/working/OvercookedAI-coop/Game.py", line 7, in <module>
#     from Game import Game
#   File "/kaggle/working/OvercookedAI-coop/Game.py", line 7, in <module>
#     from Game import Game
# ImportError: cannot import name 'Game' from partially initialized module 'Game' (most likely due to a circular import) (/kaggle/working/OvercookedAI-coop/Game.py)
